# %% [markdown]
# ### Boolean string functions

# %%
#True or False answer

# %% [markdown]
# ### 11)startswith()

# %%
s="I am here to learn python"  
s.startswith("t")        #checks the starting alphabet,space counts
# Out:
# False

# %%
s.startswith("I")
# Out:
# True

# %%
s.startswith("i")
# Out:
# False

# %% [markdown]
# ### 12)endswith()

# %%
s
# Out:
# 'I am here to learn python'

# %%
s.endswith("n")     #checks the starting alphabet
# Out:
# True

# %%
s.endswith("N")
# Out:
# False

# %%
l=["chetana","nikita","sejal"]
for i in l:
    if i.endswith("a"):
        print(i)
# Out:
# chetana
# nikita

# %% [markdown]
# ### 13)isalpha()

# %%
#only alphabets counts space

# %%
print(s)
# Out:
# I am here to learn python

# %%
s
# Out:
# 'I am here to learn python'

# %%
# checks the alphabets 
#space matters means if space present it gives false answer
s.isalpha()
# Out:
# False

# %%
d="trupti "   #space not present hence true
d.isalpha()
# Out:
# False

# %%
s1="learn "
s1.isalpha()
# Out:
# False

# %% [markdown]
# ### 14)isalnum()

# %%
#only alphabets, only digits, combination of both, space matters

# %%
s1="chetana"
s2="1234"
s3="chetana1233"
s4="chetana13 "
s5="chetana 234"
print(s1.isalnum())
print(s2.isalnum())
print(s3.isalnum())
print(s4.isalnum())
print(s5.isalnum())
# Out:
# True
# True
# True
# False
# False

# %% [markdown]
# ### 15)isspace()

# %%
#only spaces

# %%
s6="dsbcfjs "
s7="    "
s8=""
print(s6.isspace())
print(s7.isspace())
print(s8.isspace())
# Out:
# False
# True
# False

# %% [markdown]
# ### 16)isdigit()

# %%
#only digits, spaces matter

# %%
p1="11425"
p2="dh1212"
p3="3434 "
print(p1.isdigit())
print(p2.isdigit())
print(p3.isdigit())
# Out:
# True
# False
# False

# %% [markdown]
# ### 17)islower()

# %%
#space dosent matter
k1="DATA SCIENCE"
k1.islower()
# Out:
# False

# %%
k2="Data Science"
k2.islower()
# Out:
# False

# %% [markdown]
# ### 18)isupper()

# %%
k1.isupper()
# Out:
# True

# %%
k2.isupper()
# Out:
# False

# %% [markdown]
# ### 19)index()

# %%
k1
# Out:
# 'DATA SCIENCE'

# %%
k1.index("A")  # indexing starts with 0 and space counts
# Out:
# 1

# %%
k1.index("s")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 k1.index("s")
#
# ValueError: substring not found

# %%
k1.index("L")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 k1.index("L")
#
# ValueError: substring not found

# %%
k1.find("D")
# Out:
# 0

# %%
k1.index("D")
# Out:
# 0

# %%
k1.index("d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 k1.index("d")
#
# ValueError: substring not found

# %%
k1.find("d")
# Out:
# -1

# %%
k1.find("P")
# Out:
# -1

# %%
k1.index("P")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 k1.index("P")
#
# ValueError: substring not found

# %% [raw]
# difference between index and find function
# - index and find both returns the index value of specified character
# - index returns value error if index not found and it is case sensitive
# - find returns -1 in string and value error in list if index not found of specified character

# %% [markdown]
# ### String slicing

# %%
#extracting part of the string
#[start:end:step size] by default step size is 1
p="I am Chetana working in ipcs"

# %%
p[5:12]
# Out:
# 'Chetana'

# %%
#positive indexing and slicing
p[0:12]
# Out:
# 'I am Chetana'

# %%
p[0:12:1]
# Out:
# 'I am Chetana'

# %%
p[:12]
# Out:
# 'I am Chetana'

# %%
p[:12:1]
# Out:
# 'I am Chetana'

# %%
p[:12:2]
# Out:
# 'Ia htn'

# %%
p[:12:3]
# Out:
# 'Imha'

# %%
p[5:12]
# Out:
# 'Chetana'

# %%
p[5:12:1]
# Out:
# 'Chetana'

# %%
p[5:12:2]
# Out:
# 'Ceaa'

# %%
p[::]
# Out:
# 'I am Chetana working in ipcs'

# %%
p
# Out:
# 'I am Chetana working in ipcs'

# %%
#negative indexing and slicing
p[-7:]
# Out:
# 'in ipcs'

# %%
q="I am Chetana "
q[-8:-1]
# Out:
# 'Chetana'

# %%
#reverse using positive indexing and slicing :step -1
q[12:4:-1]
# Out:
# ' anatehC'

# %%
q[::-1]
# Out:
# ' anatehC ma I'

# %%
q[::]
# Out:
# 'I am Chetana '

# %%
q
# Out:
# 'I am Chetana '

# %%
#reverse using negative indexing and slicing :step -1
q[-2:-9:-1]
# Out:
# 'anatehC'

# %%
q[::-1]
# Out:
# ' anatehC ma I'

# %%
t="python and data science"
t[0]
# Out:
# 'p'

# %% [markdown]
# ### f string methods

# %%
a=78
b=90
c=a+b
print("addition is this:",c)
# Out:
# addition is this: 168

# %%
a=78
b=90
c=a+b
print("addition of",a,"and",b,"is this:",c)
# Out:
# addition of 78 and 90 is this: 168

# %%
#formatted string
a=78
b=9
c=a+b
print(f"addition of {a} and  {b} is this:{ c}")
# Out:
# addition of 78 and  9 is this:87

# %%
var="bark"
print(f"a dog says {var}")
print(f'a dog says {var}')
print(f"""a dog says {var}""")
# Out:
# a dog says bark
# a dog says bark
# a dog says bark

# %% [markdown]
# ### Escape character

# %%
text="we are the so called "vikings" from the north"
# Out:
#   Cell In[23], line 1
#     text="we are the so called "vikings" from the north"
#                                 ^
# SyntaxError: invalid syntax

# %%
text="we are the so called , vikings from the north"
text
# Out:
# 'we are the so called , vikings from the north'

# %%
text="we are the so called \"vikings\" from the north"
print(text)
# Out:
# we are the so called "vikings" from the north

# %%
text="we are the so called vikings \"from\" the north"
print(text)
# Out:
# we are the so called vikings "from" the north

# %%
text="we are the so called vikings \'from\' the north"
print(text)
# Out:
# we are the so called vikings 'from' the north

# %%
text="we are the so called vikings \from\? the north"   #f got erase bcz of \(backslash)
print(text)
# Out:
# we are the so called vikings rom\? the north

# %%
#The r prefix tells Python to treat the string literally,
#meaning that backslashes will not be interpreted as escape characters.
text = r"we are the so called vikings from? the north"   #? is not special character so escape character doest not work on it
print(text)
# Out:
# we are the so called vikings from? the north

# %%
text="we are the so called \\vikings\\ from the north"
print(text)
# Out:
# we are the so called \vikings\ from the north

# %% [markdown]
# ### new line

# %%
text="we are the so called \nvikings from the north"  #\n
print(text)
# Out:
# we are the so called
# vikings from the north

# %% [markdown]
# ### \t:tab

# %%
text="we are the so called \tvikings from the north"
print(text)
# Out:
# we are the so called 	vikings from the north

# %% [markdown]
# ### \b:backspace

# %%
text="we are the so calle\bd\b  vikings\b from the north"
print(text)
# Out:
# we are the so call  viking from the north

# %% [markdown]
# ### \r:carriage return

# %%
#carriage return
#carriage return left side=right side,space counts
text="we are the so called  \rvikings from the north"
print(text)
# Out:
# vikings from the north

# %%
text="we are the so called vikings from \rthe north" #34 = 9
print(text)
# Out:
# the northe so called vikings from

# %%
text="we are \rthe so called vikings from the north"  #34-9=25
print(text)
# Out:
# the so called vikings from the north

# %%
s="my name is \rchetana"  #11-7=4
print(s)
# Out:
# chetana is

# %%
y="I am aa\rhere"
print(y)
# Out:
# here aa

# %% [markdown]
# ### Strip()

# %% [markdown]
# remove any leading and trailing whitespace ,characters (such as spaces, tabs, and newlines)

# %%
text = "  Hello, Welcome!  "
result = text.strip()
print(result)  # Output: "Hello, World!"
# Out:
# Hello, Welcome!

# %%
text = "@@@Hello, World!@@@"
result = text.strip("@")
print(result)  # Output: "Hello, World!"
# Out:
# Hello, World!

# %%
text = "@@@Hello, World!@@@"
result = text.lstrip("@")
print(result)  # Output: "Hello, World!"
# Out:
# Hello, World!@@@

# %%
text = "@@@Hello, World!eee"
result = text.rstrip("e")
print(result)  # Output: "Hello, World!"
# Out:
# @@@Hello, World!

# %% [markdown]
# ### Split()

# %% [markdown]
# it splits the string at whitespace characters (spaces, tabs, or newlines)

# %%
text = "Python and Data Science "
result = text.split()
print(result)
# Out:
# ['Python', 'and', 'Data', 'Science']

# %%
text = "Python,and,Data,Science "
result = text.split(",")
print(result)
# Out:
# ['Python', 'and', 'Data', 'Science ']

# %%
text = "one two three four"
result = text.split(" ",1)
print(result)  # Output: ['one', 'two', 'three four']
#the string is split at the first two spaces
# Out:
# ['one', 'two three four']
