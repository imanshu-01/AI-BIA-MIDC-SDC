# %% [markdown]
# Tuple:
#  - () or ,
#  - (1,2,3,4) or 1,2,3,4
#  - Ordered :slicing/indexing
#  - immutable
#  - multiple data type allows
#  - duplicates allow

# %%
t1=(4,7,4,8,"samiksha",True,[1,2,3],(1,2,4))
print(t1)
# Out:
# (4, 7, 4, 8, 'samiksha', True, [1, 2, 3], (1, 2, 4))

# %%
t2=1,2,3,4
print(t2)
# Out:
# (1, 2, 3, 4)

# %%
t3=(1,2,1,2,3,(10,100),[1,2,4])
print(t3)
# Out:
# (1, 2, 1, 2, 3, (10, 100), [1, 2, 4])

# %%
t3[3]
# Out:
# 2

# %%
t3[5][1]
# Out:
# 100

# %%
t3[6][0]
# Out:
# 1

# %%
t3[0:4]
# Out:
# (1, 2, 1, 2)

# %%
t1
# Out:
# (4, 7, 4, 8, 'samiksha', True, [1, 2, 3], (1, 2, 4))

# %%
t1[0:4:2]
# Out:
# (4, 4)

# %%
#tuple is immutable still if we want to add, change ,remove elements in tuple then we will do type casting
list_t1=list(t1)    #convert tuple into a list
list_t1
# Out:
# [4, 7, 4, 8, 'samiksha', True, [1, 2, 3], (1, 2, 4)]

# %%
list_t1.append("yash")    # to add a particular element

# %%
list_t1
# Out:
# [4, 7, 4, 8, 'samiksha', True, [1, 2, 3], (1, 2, 4), 'yash']

# %%
t1=tuple(list_t1)  #type casting
t1
# Out:
# (4, 7, 4, 8, 'samiksha', True, [1, 2, 3], (1, 2, 4), 'yash')

# %%
list_t1.remove("samiksha")     # to remove a particular element 
list_t1
# Out:
# [4, 7, 4, 8, True, [1, 2, 3], (1, 2, 4), 'yash']

# %%
t1=tuple(list_t1)      #convert list into a tuple
t1
# Out:
# (4, 7, 4, 8, True, [1, 2, 3], (1, 2, 4), 'yash')

# %% [markdown]
# ### Delete:del

# %%
s="python"  #immuatble
l=[1,2,3]   #mutable
t=5,6,78    #immuatble

# %%
del s[0]
s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 del s[0]
#       2 s
#
# TypeError: 'str' object doesn't support item deletion

# %%
s[1:6]   #string slicing
# Out:
# 'ython'

# %%
del l[0]    # deletes the 0th element

# %%
l
# Out:
# [2, 3]

# %%
del t[0]   #does not delete
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 del t[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del s

# %%
del l

# %%
del t

# %%
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(s)
#
# NameError: name 's' is not defined

# %%
print(t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(t)
#
# NameError: name 't' is not defined

# %% [markdown]
# #### packing and unpacking the tuple

# %%
t=("chetana@gmail.com","chetana123")

# %%
a,b=t            #packing

# %%
a  #@unpacking
# Out:
# 'chetana@gmail.com'

# %%
b
# Out:
# 'chetana123'

# %%
t=1,2,3,4,6,7,8,(9,0)
a,b,c,d,e,f,g,h=t   #packing

# %%
e  #unpacking
# Out:
# 6

# %%
h
# Out:
# (9, 0)

# %%
t=1,2,3,4,6,7,8
a,b,c,d,e,f=t   #packing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 2
#       1 t=1,2,3,4,6,7,8
# ----> 2 a,b,c,d,e,f=t
#
# ValueError: too many values to unpack (expected 6)

# %% [markdown]
# #### count() and index()

# %%
s="python"  #immuatble
l=[1,2,3]   #muatble
t=5,6,78    #immuatble

# %%
#ordered:index()==>position
s.index("h")
# Out:
# 3

# %%
s.index("ython")
# Out:
# 1

# %%
s.index("oy")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s.index("oy")
#
# ValueError: substring not found

# %%
s.index("yu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 s.index("yu")
#
# ValueError: substring not found

# %%
s.index("on")
# Out:
# 4

# %%
s.count("h")
# Out:
# 1

# %%
l
# Out:
# [1, 2, 3]

# %%
l.index(3)
# Out:
# 2

# %%
t
# Out:
# (5, 6, 78)

# %%
t.index(78)
# Out:
# 2

# %%
t.count(78)
# Out:
# 1
