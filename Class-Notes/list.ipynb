# %% [markdown]
# list:
#  - [] it will allow multiple types of elements
#  - it will allow duplicate elements
#  - indexing,slicing
#  - ordered
#  - mutable(change,add,remove)

# %%
list_1=[1,2,3,3,4,6]
list_2=["A","b","C"]
list_3=[1,3,5,"car"]
list_4=[1,3.0,"car",True,[1,3,"net"]]

# %%
list1=[1,1,2,4,45.5,"nikhil",True,[10,20]]  #int,float,string,boolean,list
print(list1)
# Out:
# [1, 1, 2, 4, 45.5, 'nikhil', True, [10, 20]]

# %%
list3=[1,3,45,(9,0)]
list3
# Out:
# [1, 3, 45, (9, 0)]

# %%
list3[3]
# Out:
# (9, 0)

# %%
list1[5]
# Out:
# 'nikhil'

# %%
list1[7][0]   #nested indexing
# Out:
# 10

# %%
list1[7][1]
# Out:
# 20

# %%
list1[-1][-2]
# Out:
# 10

# %%
list1[-6]
# Out:
# 2

# %% [markdown]
# ### Changing elements using index

# %%
list1
# Out:
# [1, 1, 2, 4, 45.5, 'nikhil', True, [10, 20]]

# %%
list1[0]=34

# %%
list1
# Out:
# [34, 1, 2, 4, 45.5, 'nikhil', True, [10, 20]]

# %%
list1[5]=56

# %%
print(list1)
# Out:
# [34, 1, 2, 4, 45.5, 56, True, [10, 20]]

# %%
list1[-1][-2]="chetana"
list1
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20]]

# %% [markdown]
# ### List Slicing

# %%
list1
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20]]

# %%
list1[1:4]
# Out:
# [1, 2, 4]

# %%
list1[0:4]
# Out:
# [34, 1, 2, 4]

# %%
list1[2:5]
# Out:
# [2, 4, 45.5]

# %%
list1[7][0][0:3]
# Out:
# 'che'

# %%
list1[-1][-2][0:3]
# Out:
# 'che'

# %%
list1[-1][0][0:4]
# Out:
# 'chet'

# %%
list2=[1,3.0,"car",True,[1,3,"net"]]
list2[4][2][0:2]
# Out:
# 'ne'

# %%
list2[-1][-1][-3:-1]
# Out:
# 'ne'

# %% [markdown]
# #### Adding the elements using function

# %% [markdown]
# #### single element: append()

# %%
list1
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20]]

# %%
list1.append(500)
print(list1)
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500]

# %%
list1.append(68)
list1
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68]

# %%
list1.append(87,89)
list1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 list1.append(87,89)
#       2 list1
#
# TypeError: list.append() takes exactly one argument (2 given)

# %% [markdown]
# #### multiple elements: extend()

# %%
list1.extend(["nikhil",5,8])
print(list1)
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68, 'nikhil', 5, 8]

# %%
list1.extend([67])
list1
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68, 'nikhil', 5, 8, 67]

# %%
list1.extend([["nikhil",5,8]])  #added the list["nikhil",5,8] in list1
print(list1)
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68, 'nikhil', 5, 8, 67, ['nikhil', 5, 8]]

# %% [markdown]
# ### insert()

# %%
print(list1)
# Out:
# [34, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68, 'nikhil', 5, 8, 67, ['nikhil', 5, 8]]

# %%
list1.insert(1,500)  #insert() insert the element to a particular index mention in insert()
print(list1)
# Out:
# [34, 500, 1, 2, 4, 45.5, 56, True, ['chetana', 20], 500, 68, 'nikhil', 5, 8, 67, ['nikhil', 5, 8]]

# %%
fruits=["apple","banana","cherry"]

# %%
fruits.insert(0,"orange")

# %%
fruits
# Out:
# ['orange', 'apple', 'banana', 'cherry']

# %%
fruits[0]="watermilon"
fruits
# Out:
# ['watermilon', 'apple', 'banana', 'cherry']

# %%
fruits.insert(2,["grapes","kiwi"])
fruits
# Out:
# ['watermilon', 'apple', ['grapes', 'kiwi'], 'banana', 'cherry']

# %% [markdown]
# #### Removing the elements

# %%
list1=[1,1,2,4,45.5,"nikhil",True,[10,20]]
#list1.remove(1)
#print(list1)

# %%
list1.remove(1)   #multiple elements cannot remove
print(list1)
# Out:
# [1, 2, 4, 45.5, 'nikhil', True, [10, 20]]

# %%
list1.remove("nikhil")
print(list1)
# Out:
# [1, 2, 4, 45.5, True, [10, 20]]

# %%
list1.remove(4)   #if two same elements are present then it remove 1st one only
print(list1)
# Out:
# [1, 2, 45.5, True, [10, 20]]

# %%
list1.pop()   #removes only last element of list
# Out:
# [10, 20]

# %%
list1
# Out:
# [1, 2, 45.5, True]

# %%
list1.pop()
# Out:
# True

# %%
list1
# Out:
# [1, 2, 45.5]

# %%
len(list1)
# Out:
# 3

# %%
list2=[2,3,4,8,99,0,7]

# %%
len(list2)
# Out:
# 7

# %%
fruits
# Out:
# ['watermilon', 'apple', ['grapes', 'kiwi'], 'banana', 'cherry']

# %%
fruits.count("apple")
# Out:
# 1

# %%
fruits=["apple","apple","banana","cherry"]
fruits.count("apple")
# Out:
# 2

# %%
fruits.count("ch")
# Out:
# 0

# %%
fruits[2].count("a")
# Out:
# 3

# %%
fruits[3].count("r")
# Out:
# 2

# %%
fruits[0:2].count("a")
# Out:
# 0

# %%
fruits.count("a")
# Out:
# 0

# %%
l=[4,956,956,9,5,2,5,-1]
max(l)   #shows the maximum value element
# Out:
# 956

# %%
min(l)    #shows the minimum value element
# Out:
# -1

# %%
sum(l)   #do sum of all elements in the list ==>4+956+956+9+5+2+5-1=1937
# Out:
# 1936

# %%
l1=[2,3,4,"ujl"]
sum(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[127], line 2
#       1 l1=[2,3,4,"ujl"]
# ----> 2 sum(l1)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
max(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 max(l1)
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
min(l1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 min(l1)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l
# Out:
# [4, 956, 956, 9, 5, 2, 5, -1]

# %%
l.sort()    #arrange elements in ascending order
print(l)
# Out:
# [-1, 2, 4, 5, 5, 9, 956, 956]

# %%
l.sort(reverse=True)   #arrange elements in descending order
print(l)
# Out:
# [956, 956, 9, 5, 5, 4, 2, -1]

# %%
words = ["Python", "and", "Data Science"]
result = " ".join(words)
print(result)
# Out:
# Python and Data Science

# %%
words = ["apple", "banana", "cherry"]
result = ", ".join(words)
print(result)
# Out:
# apple, banana, cherry

# %%
l1=[9,8]
l2=[6,7]
l=l2+l1
l
# Out:
# [6, 7, 9, 8]
