# %% [markdown]
# # Python Exception Handling

# %% [markdown]
# Exception===Error

# %% [markdown]
# There are two types of error:
#   - syntax error(complied time error)
#   - logical error(run time error)-exceptions

# %%
print(dir(locals()["__builtins__"]))
# Out:
# ['ArithmeticError', 'AssertionError', 'AttributeError', 'BaseException', 'BaseExceptionGroup', 'BlockingIOError', 'BrokenPipeError', 'BufferError', 'BytesWarning', 'ChildProcessError', 'ConnectionAbortedError', 'ConnectionError', 'ConnectionRefusedError', 'ConnectionResetError', 'DeprecationWarning', 'EOFError', 'Ellipsis', 'EncodingWarning', 'EnvironmentError', 'Exception', 'ExceptionGroup', 'False', 'FileExistsError', 'FileNotFoundError', 'FloatingPointError', 'FutureWarning', 'GeneratorExit', 'IOError', 'ImportError', 'ImportWarning', 'IndentationError', 'IndexError', 'InterruptedError', 'IsADirectoryError', 'KeyError', 'KeyboardInterrupt', 'LookupError', 'MemoryError', 'ModuleNotFoundError', 'NameError', 'None', 'NotADirectoryError', 'NotImplemented', 'NotImplementedError', 'OSError', 'OverflowError', 'PendingDeprecationWarning', 'PermissionError', 'ProcessLookupError', 'RecursionError', 'ReferenceError', 'ResourceWarning', 'RuntimeError', 'RuntimeWarning', 'StopAsyncIteration', 
# ...

# %% [markdown]
# # Syntax error
#
# - error caused by not following the rules or proper structure(syntax) of the language is called syntax error or parsing error.

# %%
a=20

if a>10
    print(a)  #syntax error
# Out:
#   Cell In[3], line 3
#     if a>10
#            ^
# SyntaxError: expected ':'

# %%
a=20
b=0  #logical error

if a>10:
    a/b
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[34], line 5
#       2 b=0  #logical error
#       4 if a>10:
# ----> 5     a/b
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## Logical error Error(Exception)
#
# - error that occur at runtime(after passing the syntax test) are called exceptions or logical error
# - trying to open a file for reading that doesnt exist---- (File not found error)
# - try to divide a number by zero(Zero division error)
# - try to import a module that doenst not exist (Import error)

# %%
import panda

# syntax error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 import panda
#
# ModuleNotFoundError: No module named 'panda'

# %%
import pandas

# %%
import pytorch
#pip install pytorch
# logical error becoz i havent installed teh lib or module
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 import pytorch
#
# ModuleNotFoundError: No module named 'pytorch'

# %% [markdown]
# ## Exceptions in Python
#
# Python has many built-in exceptions that are raised when your program encounters an error (something in the program goes wrong).
#
# When these exceptions occur, the Python interpreter stops the current process and passes it to the calling process until it is handled. If not handled, the program will crash.

# %%
print("**")

print("**")
print("**")
print("**")

1/0
# Out:
# **
# **
# **
# **
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[9], line 7
#       4 print("**")
#       5 print("**")
# ----> 7 1/0
#
# ZeroDivisionError: division by zero

# %%
print("**")

1/0
print("**")
print("**")
print("**")
# Out:
# **
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 print("**")
# ----> 3 1/0
#       4 print("**")
#       5 print("**")
#
# ZeroDivisionError: division by zero

# %% [markdown]
# # Catching Exceptions in Python
#
# In Python, exceptions can be handled using a try statement.
#
# The critical operation which can raise an exception is placed inside the try clause. The code that handles the exceptions is written in the except clause.

# %%
# syntax

try:
    code
    
    
    
except:

# %%
print("**1")
print("***2")
print("**3")
try:
    print("**")
    a=1
    b=1
    a/b
    print("**")
    print("**")
    print("**")
    
    
except:
    print("Something wrong happend, Please try after sometime")
    
    
print("*4*")
print("**5")
print("*6*")
# Out:
# **1
# ***2
# **3
# **
# **
# **
# **
# *4*
# **5
# *6*

# %%
print("**1")
print("***2")
print("**3")

print("**")
a=1
b=0
a/b
print("**")
print("**")
print("**")
    
    

    
    
print("*4*")
print("**5")
print("*6*")
# Out:
# **1
# ***2
# **3
# **
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [9], in <cell line: 8>()
#       6 a=1
#       7 b=0
# ----> 8 a/b
#       9 print("**")
#      10 print("**")
#
# ZeroDivisionError: division by zero

# %%
print("**1")
print("***2")
print("**3")
try:
    print("**")
    a=1
    b=0
    a/b
    print("**")
    print("**")
    print("**")
    
    
except:
    print("Something wrong happend, Please try after sometime")
    
    
print("*4*")
print("**5")
print("*6*")
# Out:
# **1
# ***2
# **3
# **
# Something wrong happend, Please try after sometime
# *4*
# **5
# *6*

# %%
print("**1")
print("***2")
print("**3")
try:
    print("**")
    a=1
    b=0
    a/b
    print("**")
    print("**")
    print("**")
    
    
except:
     pass
     print("Raise zero division error")
    
print("*4*")
print("**5")
print("*6*")
# Out:
# **1
# ***2
# **3
# **
# Raise zero division error
# *4*
# **5
# *6*

# %% [markdown]
# - python built-in exceptions

# %%
a="as"
b=1

a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 a="as"
#       2 b=1
# ----> 4 a+b
#
# TypeError: can only concatenate str (not "int") to str

# %%
try:
    a="as"
    b=123
    print(a+b)
except:
    print("we cant add string and integers together")
# Out:
# we cant add string and integers together

# %%
try:
    a=1
    b=123
    print(a+b)
except:
    print("we cant add string and integers together")
# Out:
# 124

# %%
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 5/0
#
# ZeroDivisionError: division by zero

# %%
Errors : builtins :Exception class

# %%
try:
    a=eval(input("enter the 1st number:"))
    b=eval(input("enter the 2nd number:"))    
    c=a/b
    
    print(c)
    
except Exception as ex:
    print("the error is:",ex,"and error name is",type(ex))
# Out:
# enter the 1st number: 1
# enter the 2nd number: 0
# the error is: division by zero and error name is <class 'ZeroDivisionError'>

# %% [markdown]
# ### Exception is class which contains built in errors

# %%
try:
    import pytorch
    
    
    
    
except Exception as tp:
    print("the error is:",tp)
    print("and error name is:",type(tp))
# Out:
# the error is: No module named 'pytorch'
# and error name is: <class 'ModuleNotFoundError'>

# %%
try:
    import pytorch
    
    
    
    
except:
    print("please first installed the module and then import")
# Out:
# please first installed the module and then import

# %%
int("a")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 int("a")
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
int("1")
# Out:
# 1

# %%
int(0.8)
# Out:
# 0

# %%
float(1)
# Out:
# 1.0

# %%
float("s")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 float("s")
#
# ValueError: could not convert string to float: 's'

# %%
def division_check():
    try:
        a=int(input("enter the numerator:"))
        b=int(input("enter the denominator:"))
        c=a/b
        print(c)
        
    
    except Exception as ex1:
        print("The program crashed becoz of this error:",ex1)
        print("enter a non-zero deno value to proceed")
        division_check()  #recurssion

division_check()
# Out:
# enter the numerator: 1
# enter the denominator: 0
# The program crashed becoz of this error: division by zero
# enter a non-zero deno value to proceed
# enter the numerator: 1
# enter the denominator: 0
# The program crashed becoz of this error: division by zero
# enter a non-zero deno value to proceed
# enter the numerator: 1
# enter the denominator: 9
# 0.1111111111111111

# %%
a=2
if a>10:
print("a")
# Out:
#   Cell In[3], line 3
#     print("a")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
try:
    a=eval(input("enter the number1:"))
    b=eval(input("enter the number2:"))

    c=a/b
    print(c)
#1.Zerodivision error
    
except ZeroDivisionError as prachi:
    print("zero division error",prachi,"please enter non-zero value in b")

except TypeError as t1:  #String values enter
    print("type error:",t1,"please enter int value in a and b")
    
except SyntaxError as s1: 
    print("syntax error",s1,"Please check the syntax")
    
except Exception as ex:
    print("the error is",ex,"and error name is",type(ex))
# Out:
# enter the number1: "rr"
# enter the number2: kk
# the error is name 'kk' is not defined and error name is <class 'NameError'>

# %%
a="1
b=0
# Out:
#   Input In [13]
#     a="1
#         ^
# SyntaxError: EOL while scanning string literal

# %%
1/"a"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 1/"a"
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# # Python try with else clause
#
# In some situations, you might want to run a certain block of code if the code block inside try ran without any errors. For these cases, you can use the optional else keyword with the try statement.

# %%
try:
    a=1
    b=4
    
    c=a/b
    d=a*b
    e=a+b
    

    
except Exception as ex:
    print(ex)
    
else:
    print(a)
    print(b)
    print(c)
    print(d)
    print(e)
    
print("this is last line")
# Out:
# 1
# 4
# 0.25
# 4
# 5
# this is last line

# %%
try:   #when my try runs then only else runs
    a=1
    b=0
     
   
    c=a/b
    d=a*b
    e=a+b
    

    
except Exception as ex:
    print(ex)
    
else:
    print(a)
    print(b)
    print(c)
# Out:
# division by zero

# %% [markdown]
# will go in else, if no error or exception.
# and if exception then will go in except and will skip else

# %% [markdown]
# # Python try...finally
#
# The try statement in Python can have an optional finally clause. This clause is executed no matter what, and is generally used to release external resources.
#
# For example, we may be connected to a remote data center through the network or working with a file or a Graphical User Interface (GUI).
#
# In all these circumstances, we must clean up the resource before the program comes to a halt whether it successfully ran or not. These actions (closing a file, GUI or disconnecting from network) are performed in the finally clause to guarantee the execution.

# %%
try:
    f=open(r"C:\Users\admin\Desktop\Data Science\File Oprations\mohit.txt",mode="r")
    #f.read()
    for i in f:
        print(i)
   
except Exception as ex:
    print(ex,"file not found")
    
#     opertaions

finally:
    f.close()
# Out:
# my name is chetana

# %%
try:
    f=open(r"C:\Users\admin\Desktop\Data Science\File Oprations\mohit.txt",mode="w")
    #f.read()
    f.write("data science")
   
except Exception as ex:
    print(ex,"check the file path")
    #     opertaions

finally:
    f.close()
# Out:
# [Errno 2] No such file or directory: 'C:\\Users\\admin\\Desktop\\Data Science\\File Oprations\\mohit.txt' check the file path
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 11
#       7     print(ex,"check the file path")
#       8     #     opertaions
#       9
#      10 finally:
# ---> 11     f.close()
#
# NameError: name 'f' is not defined

# %%
f=open("my.txt",mode="r")
f.read()
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 f=open("my.txt",mode="r")
#       2 f.read()
#       3 f.close()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'my.txt'

# %%
try:
    a=1
    b=0
    c=a/b
    d=a*b
    e=a+b
    

    
except Exception as ex:
    print(ex)

else:
    print(a)
    print(b)
    print(c)
    
    
finally:
    print("the code is complete")
# Out:
# division by zero
# the code is complete

# %% [markdown]
# ### Python Custom Exceptions
# Python has numerous built-in exceptions that force your program to output an error when something in the program goes wrong.
#
# However, sometimes you may need to create your own custom exceptions that serve your purpose.

# %% [markdown]
# ### Creating Custom Exceptions
# In Python, users can define custom exceptions by creating a new class. This exception class has to be derived, either directly or indirectly, from the built-in Exception class. Most of the built-in exceptions are also derived from this class.

# %% [markdown]
# # Syntax

# %%
class zerodivision(Exception):
    pass

# %%
class CustomException(Exception):
    """ my custom exception class """


try:
    raise CustomException('This is my custom exception or error')
except CustomException as ex:
    print(ex)
# Out:
# This is my custom exception or error

# %%
#Exception

# %%
class Error_for_negative(Exception):
    pass

# %%
a=int(input('enter a postive no:'))

if a<0:
    raise Error_for_negative("You have enter nagetive no.,plese enter positive no.")
else:
    print(a,"This is a positive no.")
# Out:
# enter a postive no: -8
# ---------------------------------------------------------------------------
# Error_for_negative                        Traceback (most recent call last)
# Cell In[4], line 4
#       1 a=int(input('enter a postive no:'))
#       3 if a<0:
# ----> 4     raise Error_for_negative("You have enter nagetive no.,plese enter positive no.")
#       5 else:
#       6     print(a,"This is a positive no.")
#
# Error_for_negative: You have enter nagetive no.,plese enter positive no.

# %%
class Error_for_negative(Exception):
    pass
try:
    a=int(input('enter a postive no:'))
    if a<0:
        raise Error_for_negative

    else:
        
        print(a," is positive no:")
        
except Error_for_negative :
    print("Not a postive no, enter postive no")
# Out:
# enter a postive no:-9
# Not a postive no, enter postive no

# %%
a=int(input('enter no1:'))
b=int(input('enter no2:'))
if b==0:
    raise ZeroDivisionError("division by zero is not possible")
else:
    print(a/b)
# Out:
# enter no1: 5
# enter no2: 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[6], line 4
#       2 b=int(input('enter no2:'))
#       3 if b==0:
# ----> 4     raise ZeroDivisionError("division by zero is not possible")
#       5 else:
#       6     print(a/b)
#
# ZeroDivisionError: division by zero is not possible

# %%
a=int(input('enter no1:'))
b=int(input('enter no2:'))

print(a/b)
# Out:
# enter no1:4
# enter no2:0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[41], line 4
#       1 a=int(input('enter no1:'))
#       2 b=int(input('enter no2:'))
# ----> 4 print(a/b)
#
# ZeroDivisionError: division by zero

# %%
a=int(input('enter no1:'))
b=int(input('enter no2:'))
if b==0:
    raise ZeroDivisionError("You are trying to divide by zero")
else:
    print(a/b)
# Out:
# enter no1:8
# enter no2:0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[22], line 4
#       2 b=int(input('enter no2:'))
#       3 if b==0:
# ----> 4     raise ZeroDivisionError("You are trying to divide by zero")
#       5 else:
#       6     print(a/b)
#
# ZeroDivisionError: You are trying to divide by zero

# %%
class zero_division(Exception):
    a=int(input('enter no1:'))
    b=int(input('enter no2:'))

if b==0:
    raise zero_division("You are trying to divide by zero")
# Out:
# enter no1:2
# enter no2:0
# ---------------------------------------------------------------------------
# zero_division                             Traceback (most recent call last)
# Cell In[14], line 6
#       3     b=int(input('enter no2:'))
#       5 if b==0:
# ----> 6     raise zero_division("You are trying to divide by zero")
#
# zero_division: You are trying to divide by zero

# %% [markdown]
# homework: write a program for ATM balance check and withdraw amount using try and except

# %%
class Balanceexception(Exception):
    pass

def checkbalance():
    money=10000
    money_to_withdraw=int(input("enter the money you want to withdraw"))
    balance=money-money_to_withdraw
    if balance<2000:
        raise Balanceexception
    else:
        return balance
    
try:
    balance=checkbalance()
    
    
except Balanceexception as be:
    print("Insufficent Balance, you cannot withdraw")
    
    
else:
    print("Your balance is:",balance,"you can withdrawn it sucessfully")
    
    
finally:
    print("have a good day")
# Out:
# enter the money you want to withdraw9000
# Insufficent Balance, you cannot withdraw
# have a good day

# %%
# define Python user-defined exceptions
class InvalidAgeException(Exception): #Raised when the input value is less than 18
    pass
    

try:
    age = int(input("Enter a age: "))
    if age < 18:
        raise InvalidAgeException
    else:
        print("Eligible to Vote")
        
except InvalidAgeException:
    
    print("Exception occurred: Invalid Age")
# Out:
# Enter a age:  45
# Eligible to Vote

# %% [markdown]
# ### Password validation

# %%
class invalid(Exception):
    pass
e=str(input("enter email:"))
p=str(input("enter password:"))
email="chetana123@gmail.com"
password="1234"
try:
    if (e==email and p==password):
        print("Login successfull")
    else:
        raise invalid
except invalid as i:
    print("Wrong login details")
# Out:
# enter email: chetana123@gmail.com
# enter password: 12
# Wrong login details
