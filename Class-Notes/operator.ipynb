# %% [markdown]
# ### Arithmetic operators

# %% [markdown]
# ### "+"

# %%
12+78
# Out:
# 90

# %%
23.8+1  #addition
# Out:
# 24.8

# %%
"chetana"+" "+"vasave" #joining
# Out:
# 'chetana vasave'

# %%
"DNDH"+"1677"
# Out:
# 'DNDH1677'

# %% [markdown]
# ### "-"

# %%
65-10
# Out:
# 55

# %%
6/7 #division==>QOUTIENT
# Out:
# 0.8571428571428571

# %%
6//7   #floor division==>consider only int part==>eliminates floating part
# Out:
# 0

# %%
34/7
# Out:
# 4.857142857142857

# %%
34//7
# Out:
# 4

# %% [raw]
# In Python, floor division is performed using the // operator. Floor division divides two numbers and returns the largest integer less than or equal to the result of the division. This effectively rounds the result down to the nearest whole number.

# %%
8%4  #modulus==>answer=remainder
# Out:
# 0

# %%
2**3  #power
# Out:
# 8

# %%
12*12  #multiplication
# Out:
# 144

# %% [markdown]
# #### Assignment operator

# %%
a=78
print(a)
# Out:
# 78

# %% [markdown]
# #### +=

# %%
x=6
x+=7    #x=x+7=6+7=13

# %%
x
# Out:
# 13

# %% [markdown]
# #### -=

# %%
a=9
a-=6 #a=a-6=9-6=3

# %%
a
# Out:
# 3

# %% [markdown]
# ##### *=

# %%
p=8
p*=4  #p=p*4=8*4=32

# %%
print(p)
# Out:
# 32

# %% [markdown]
# ## Logical operator

# %% [markdown]
# #### and operator

# %%
a=80
b=90

# %%
a>10 and b<9   #T(1) * F(0)==F
# Out:
# False

# %% [raw]
#  A      B
# True   True     True
# True   False    False
# False  True     False
# False  False    False

# %%
a>10 and b>9   #1 * 1  =1==>true   #multiplication
# Out:
# True

# %% [markdown]
# ### or operator

# %%
a=80
b=90

a>40 or b<80   #T(1) + F(0)
# Out:
# True

# %% [raw]
#   A     B
# True   True     True
# True   False    True
# False  True     True
# False  False    False

# %%
a<10 or b<9   #F(0) + F(0)   #addition
# Out:
# False

# %% [markdown]
# ### & operator

# %%
4&5
# Out:
# 4

# %% [raw]
# 4=0100         #binary representation of 4
# 5=0101         #binary representation of 5
# -------
# 4=0100         #output of 4 & 5 operation

# %%
13 & 17
# Out:
# 1

# %% [raw]
# 13=0000 1101      #binary representation of 13
# 17=0001 0001      #binary representation of 17
# ----------------
# 01=0000 0001     #output of 13&17 operation

# %% [raw]
# 128 64 32 16 8 4 2 1

# %%
13 | 17
# Out:
# 29

# %% [raw]
# 13=0000 1101      #binary representation of 13
# 17=0001 0001      #binary representation of 17
# ----------------
# 29=0001 1101      #output of 13|17 operation

# %%
x=8
x&=5  #x=x&5
#1000
#0101

# %%
x
# Out:
# 0

# %% [markdown]
# #### not operator

# %%
~78
# Out:
# -79

# %%
x=-5  #-5+1=-4==>-(-4)==>4
~x
# Out:
# 4

# %%
~67
# Out:
# -68

# %% [markdown]
# ### Bitwise operators

# %% [markdown]
# ### Bitwise AND

# %%
x=3
y=5
x & y
# Out:
# 1

# %% [raw]
# 0000 0000
#      32 16 8 4 2 1
#         2*3 2*2  2*1  2*0

# %% [raw]
# 3= 0011    #binary representation of 3
# 5= 0101    #binary representation of 5
# ----------
#    0001==>1

# %%
a=12
b=18
a&b
# Out:
# 0

# %% [raw]
# 12=0000 1100
# 18=0001 0010
# ---------------
#    0000 0000==>0

# %% [markdown]
# ### Membership operators

# %%
l=[1,2,3,4]
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
s={3,4,5,6}
6 in s
# Out:
# True

# %%
1 in s
# Out:
# False

# %%
7 not in s
# Out:
# True

# %% [markdown]
# ### Relational operators

# %%
a=93
b=90
a==b
# Out:
# False

# %%
a!=b  #not equal to
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %% [markdown]
# ### Identity operator

# %%
is and is not

# %%
x=5.8
if type(x) is int:
    print("Yes")
else:
    print("no")
# Out:
# no

# %%
x=5
if type(x) is int:
    print("Yes")
else:
    print("no")
# Out:
# Yes

# %%
x=9.9
if type(x) is float:
    print("yes")
else:
    print("no")
# Out:
# yes

# %% [markdown]
# #### eval()

# %% [raw]
# In Python, the eval() function is used to evaluate a string as a Python expression. It can execute a string containing a Python expression and return the result of that expression.

# %%
a=float(input("enter first no:"))
# Out:
# enter first no: 8.9

# %%
a=eval(input("enter first no:"))
# Out:
# enter first no: 4

# %%
a=eval(input("enter the list"))
# Out:
# enter the list [1,2,3,34,0]

# %%
2*(x)+8+y*5*z
x=7
y=5
z=8
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 2*(x)+8+y*5*z
#       2 x=7
#       3 y=5
#
# NameError: name 'y' is not defined

# %%
x=7
y=5
z=8
2*x+8+y*5*z
# Out:
# 222

# %%
a="2*x+8+y*5*z"
x=7
y=5
z=8
sol=eval(a)

# %%
sol
# Out:
# 222

# %%
x = 10
result = eval("x + 2")
print(result)  # Output: 12
# Out:
# 12

# %% [markdown]
# #### left right associativity

# %%
(5+8)*7  #==>left to right
# Out:
# 91

# %%
5*2//3
# Out:
# 3

# %%
10//3
# Out:
# 3

# %%
5*(2//3)
# Out:
# 0

# %%
2//3 #only int part
# Out:
# 0

# %% [markdown]
# ### right-left associativity of **

# %%
2**3**2   #<== right to left
# Out:
# 512

# %%
2**9
# Out:
# 512

# %%
(2**3)**2  #left to right
# Out:
# 64
