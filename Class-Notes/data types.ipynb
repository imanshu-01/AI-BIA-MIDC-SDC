# %% [markdown]
# ### Literals

# %% [raw]
# 1) String literals    ''or" "or""" """ eg. "abc","123"
# 2) Numeric literals  eg.123,8.9
# 3) Boolean literals eg. True or False
# 4) Collection     eg.list,tuple,sets,range
# 5) Special        eg.dict

# %% [markdown]
# #### There are 7 Data types

# %% [raw]
#  1)int,float,complex  eg. int=1,float=1.0,complex=2+j6
#  2)string-str eg.a="adbg" "123"
#  3)list       eg. l=[1,2,3]
#  4)tuple      eg. t=(1,2,3) 1,2,3
#  5)set        eg.s={1,2,3}
#  6)dict       eg.d={key:value}
#  7)bool       eg. True or False

# %%
mutable : changeble ==> we can add, remove or delete after declaration ==> list,dict,sets
immutable: non changeble ==> we cant add, remove or delete after declaration==>int,string,tuple

# %% [markdown]
# ### To checking the data types

# %%
#type(), print()  #gives data type

# %%
x=45
print(type(x))
# Out:
# <class 'int'>

# %%
y=2.0
print(type(y))
# Out:
# <class 'float'>

# %%
name="nikita"
print(type(name))
# Out:
# <class 'str'>

# %%
x=True  #False
print(type(x))
# Out:
# <class 'bool'>

# %% [markdown]
# ### Operators

# %% [raw]
# operators use in python
#
# 1) + for addition
# 2) - for substraction
# 3) * for multiplication
# 4) / for division
# 5) % for modulus
# 6) // for floor division
# 7) ** for power

# %% [markdown]
# ### 1) + for addition

# %%
a=1
b=3
#addition 
c=a+b
print("addition is this:",c)
# Out:
# addition is this: 4

# %% [markdown]
# ### 2) - for substraction

# %%
c=a-b
print("substraction is this:",c)
# Out:
# substraction is this: -2

# %% [markdown]
# ### 3) * for multiplication

# %%
c=a*b
print("multiplication is this:",c)
# Out:
# multiplication is this: 3

# %% [markdown]
# ### 4) / for division

# %%
c=a/b  #1/3  ans==>qoutient
print("division is this:",c)
# Out:
# division is this: 0.3333333333333333

# %% [markdown]
# ### 5) % for modulus

# %%
a=1
b=3
c=a%b  #answer==>remainder
print("modulus is this:",c)
# Out:
# modulus is this: 1

# %% [markdown]
# ### 6) Floor Division

# %%
a=63
b=8
c=a//b #floor division
c
# Out:
# 7

# %%
c=a/b  #division
c
# Out:
# 7.875

# %% [markdown]
# ### 7) Power

# %%
a=6
b=2
c=a**b
c
# Out:
# 36

# %% [markdown]
# # Getting input from the user

# %%
x=56
b=91
c=x+b
c
# Out:
# 147

# %%
a=int(input("enter the 1st no."))
b=int(input("enter the 2nd no."))
c=a+b
print(c)
# Out:
# enter the 1st no. 2
# enter the 2nd no. 2
# 4

# %%
name=str(input("Enter ur name: "))
surname=str(input("Enter ur surname: "))
print(name+" "+surname) #concatenation==>joining
print(name+surname)
# Out:
# Enter ur name:  yash
# Enter ur surname:  ghate
# yash ghate
# yashghate

# %% [markdown]
# ## Conversion from one data type to another

# %% [markdown]
# ### Type casting

# %%
x=123  #int
y=52.5  #float
c="chetana" #str: literals: char
b="123"    #str: literals: numeric

# %%
p=float(x)
p
# Out:
# 123.0

# %%
q=int(y)
q
# Out:
# 52

# %%
r=float(c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 r=float(c)
#
# ValueError: could not convert string to float: 'chetana'

# %%
s=int(b)
s
# Out:
# 123

# %%
t=float(b)
t
# Out:
# 123.0

# %% [markdown]
# # Exercise

# %% [markdown]
# #### find area of rectangle

# %%
#area=l*b
length=12
breadth=2.3
area=length*breadth
print("area of rectange is this:",area)
# Out:
# area of rectange is this: 27.599999999999998

# %%
#area=l*b
length=int(input("enter length:"))
breadth=int(input("enter breadth:"))
area=length*breadth
print("area of rectange is this:",area)
# Out:
# enter length: 7.8
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #area=l*b
# ----> 2 length=int(input("enter length:"))
#       3 breadth=int(input("enter breadth:"))
#       4 area=length*breadth
#
# ValueError: invalid literal for int() with base 10: '7.8'

# %%
#area=l*b
length=float(input("enter length:"))
breadth=float(input("enter breadth:"))
area=length*breadth
print("area of rectange is this:",area)
# Out:
# enter length: 5
# enter breadth: 5
# area of rectange is this: 25.0

# %% [markdown]
# #### find area of circle

# %%
#area=pi*r*r or pi*r**2

# %%
radius=2
pi=3.14
area=pi*radius*radius
area
# Out:
# 12.56

# %%
radius=2
pi=3.14
area=pi*radius**2
area
# Out:
# 12.56

# %% [markdown]
# ### perimeter of circle

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
#2*pi*r
import math
radius=2.3
perimeter_of_circle=2*math.pi*radius
print("perimeter of circle is:",perimeter_of_circle)
# Out:
# perimeter of circle is: 14.451326206513047

# %%
import math
x=int(input("enter the number"))
y=math.sqrt(x)
#y=x**0.5
print(y)
# Out:
# enter the number 91
# 9.539392014169456

# %%
y=x**0.5  #81**0.5
y
# Out:
# 8.0

# %%
math.pow(2,5)
# Out:
# 32.0

# %%
math.remainder(9,3)
# Out:
# 0.0

# %%
radius=2

area=math.pi*radius*radius
area
# Out:
# 12.566370614359172

# %% [markdown]
# ## datetime module

# %% [markdown]
# ### package/library==>modules==>functions

# %%
import statistics
print(dir(statistics.math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import datetime  #package
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
print(dir(datetime.datetime))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %% [markdown]
# ### now()

# %%
print(datetime.datetime.now())
# Out:
# 2025-11-17 14:50:12.268008

# %%
from datetime import datetime as tp

# %%
current_datetime=tp.now()
print(current_datetime)
# Out:
# 2025-11-17 14:52:01.300136

# %% [markdown]
# ### strftime()

# %%
current_datetime.strftime("%a%d/%b/%y and time is %H.%M.%S")
# Out:
# 'Mon17/Nov/25 and time is 14.52.01'

# %%
current_datetime.strftime("%a,%d/%b/%Y and time is %H.%M.%S")
# Out:
# 'Mon,17/Nov/2025 and time is 14.52.01'

# %%
current_datetime.timestamp()
# Out:
# 1763371321.300136

# %% [raw]
# The timestamp() function in Python's datetime module is used to convert a datetime object to a Unix timestamp. A Unix timestamp represents the number of seconds that have elapsed since January 1, 1970, 00:00:00 UTC (also known as the "epoch").

# %% [markdown]
# ### To get the version

# %%
import sys   #first way
print(sys.version)
# Out:
# 3.13.5 | packaged by Anaconda, Inc. | (main, Jun 12 2025, 16:37:03) [MSC v.1929 64 bit (AMD64)]

# %%
# !python --version   #second way
# Out:
# Python 3.13.5

# %%
import cmath
print(dir(cmath))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atanh', 'cos', 'cosh', 'e', 'exp', 'inf', 'infj', 'isclose', 'isfinite', 'isinf', 'isnan', 'log', 'log10', 'nan', 'nanj', 'phase', 'pi', 'polar', 'rect', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau']

# %%
#a*x*x+b*x+c=0
#(-b+-sqrt(b*b-4*a*c))/2*a
a,b,c=1,5,6
d=b*b-4*a*c
sol1=(-b+cmath.sqrt(d))/2*a
sol2=(-b-cmath.sqrt(d))/2*a
print(sol1)
print(sol2)
# Out:
# (-2+0j)
# (-3+0j)

# %%
a*sol1*sol1+b*sol1+c
# Out:
# 0j

# %%
a*sol2*sol2+b*sol2+c
# Out:
# 0j

# %% [markdown]
# ## 1)string handelling

# %% [markdown]
# - string operators

# %% [markdown]
# #### a) + operator

# %%
2+8
# Out:
# 10

# %%
a=2
b=8
c=a+b
c
# Out:
# 10

# %%
"nikita"+" "+"ghatbandhe"
# Out:
# 'nikita    ghatbandhe'

# %%
"nikita"+"vbnn"
# Out:
# 'nikitavbnn'

# %%
#concatenate(join)
a="chetana"
b="vasave"
a+" "+b
# Out:
# 'chetana vasave'

# %% [markdown]
# #### b)* operator

# %%
2*4
# Out:
# 8

# %%
a=2
b=4
c=a*b  #multiplication
c
# Out:
# 8

# %%
"chetana "*3
# Out:
# 'chetana chetana chetana '

# %%
"hello  "*5
# Out:
# 'hello  hello  hello  hello  hello  '

# %% [markdown]
# #### c)in and not in operator

# %%
#membership checked
s="python"
s1="data science"
s in s1
# Out:
# False

# %%
s="python"
s1="data science python"
s in s1
# Out:
# True

# %%
s1 in s
# Out:
# False

# %%
"a" in s1
# Out:
# True

# %%
s1 not in s
# Out:
# True

# %%
"z" in s
# Out:
# False

# %%
#membership checked
a="hello"
b="hello world"
a in b
# Out:
# True

# %%
b not in a
# Out:
# True

# %% [markdown]
# ## String functions

# %% [markdown]
# #### 1) chr

# %%
#ascii code to character
chr(35)
# Out:
# '#'

# %%
chr(97)
# Out:
# 'a'

# %%
chr(89)
# Out:
# 'Y'

# %%
chr(104)
# Out:
# 'h'

# %%
chr(45)
# Out:
# '-'

# %%
chr(90)
# Out:
# 'Z'

# %%
chr(51)
# Out:
# '3'

# %% [markdown]
# #### 2)ord()

# %%
#char to ascii
ord("#")
# Out:
# 35

# %%
ord("@")
# Out:
# 64

# %%
ord("*")
# Out:
# 42

# %%
ord("h")
# Out:
# 104

# %% [markdown]
# #### 3) len()

# %%
#space counts
#len counts starts with 1
b="hi i am here"
len(b)
# Out:
# 12

# %%
s="python and data science"
len(s)
# Out:
# 23

# %% [markdown]
# #### 4)str()

# %%
a=123 #int
b=str(a)

# %%
b
# Out:
# '123'

# %% [markdown]
# #### 5)upper()

# %%
s="python and data science"
s.upper()
# Out:
# 'PYTHON AND DATA SCIENCE'

# %% [markdown]
# #### 6)lower()

# %%
s="Python and data Science"
s.lower()
# Out:
# 'python and data science'

# %%
s2="PYTHON"
s2.lower()
# Out:
# python

# %% [markdown]
# #### 7)capitalize()

# %%
#converts only first letter of string into upper

# %%
s="python"
s.capitalize()
# Out:
# 'Python'

# %%
t="data science"
t.capitalize()
# Out:
# 'Data science'

# %%
s3="python and data science"
s3.capitalize()
# Out:
# 'Python and data science'

# %% [markdown]
# #### 8)title()

# %%
#converts all words first letter of string into upper

# %%
s3="python and data science"
s3.title()
# Out:
# 'Python And Data Science'

# %% [markdown]
# #### 9)replace()

# %%
s="data science"
s.replace("science","analytics")
# Out:
# 'data analytics'

# %%
s.replace("Science","analytics")
# Out:
# 'data science'

# %% [markdown]
# #### 10)count()

# %%
s1="data and science"
s1.count("a")
# Out:
# 3

# %%
s1.count("z")
# Out:
# 0

# %%
s1.count("data")
# Out:
# 1

# %%
s1.count("python")
# Out:
# 0
