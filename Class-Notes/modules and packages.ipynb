# %%
import statistics  #package
print(dir(statistics))
# Out:
# ['Counter', 'Decimal', 'Fraction', 'LinearRegression', 'NormalDist', 'StatisticsError', '_SQRT2', '__all__', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_coerce', '_convert', '_decimal_sqrt_of_frac', '_exact_ratio', '_fail_neg', '_float_sqrt_of_frac', '_integer_sqrt_of_frac_rto', '_isfinite', '_mean_stdev', '_normal_dist_inv_cdf', '_sqrt_bit_width', '_ss', '_sum', 'bisect_left', 'bisect_right', 'correlation', 'covariance', 'defaultdict', 'erf', 'exp', 'fabs', 'fmean', 'fsum', 'geometric_mean', 'groupby', 'harmonic_mean', 'hypot', 'linear_regression', 'log', 'math', 'mean', 'median', 'median_grouped', 'median_high', 'median_low', 'mode', 'mul', 'multimode', 'namedtuple', 'numbers', 'pstdev', 'pvariance', 'quantiles', 'random', 'reduce', 'repeat', 'sqrt', 'stdev', 'sys', 'tau', 'variance']

# %%
print(dir(statistics.math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
import math
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
math.remainder(2,1)
# Out:
# 0.0

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(5)
# Out:
# 120

# %%
from math import pow,sqrt,pi,factorial

# %%
pow(5,2)
# Out:
# 25.0

# %%
int(sqrt(81))
# Out:
# 9

# %%
pi
# Out:
# 3.141592653589793

# %%
factorial(8)
# Out:
# 40320

# %%
remainder(2,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 remainder(2,1)
#
# NameError: name 'remainder' is not defined

# %%
from math import *   # *==>mean import all or everything

# %%
import datetime #package

# %%
print(dir(datetime))
# Out:
# ['MAXYEAR', 'MINYEAR', 'UTC', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'date', 'datetime', 'datetime_CAPI', 'sys', 'time', 'timedelta', 'timezone', 'tzinfo']

# %%
#now(),strftime()
from datetime import datetime as dt
print(dir(dt))
# Out:
# ['__add__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__radd__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__rsub__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', 'astimezone', 'combine', 'ctime', 'date', 'day', 'dst', 'fold', 'fromisocalendar', 'fromisoformat', 'fromordinal', 'fromtimestamp', 'hour', 'isocalendar', 'isoformat', 'isoweekday', 'max', 'microsecond', 'min', 'minute', 'month', 'now', 'replace', 'resolution', 'second', 'strftime', 'strptime', 'time', 'timestamp', 'timetuple', 'timetz', 'today', 'toordinal', 'tzinfo', 'tzname', 'utcfromtimestamp', 'utcnow', 'utcoffset', 'utctimetuple', 'weekday', 'year']

# %%
current_date_time=dt.now()

# %%
print(current_date_time)
# Out:
# 2025-12-04 13:07:55.154401

# %%
current_date_time.strftime("%d/%m/%y")
# Out:
# '04/12/25'

# %%
current_date_time.strftime("%d/%b/%Y")
# Out:
# '04/Dec/2025'

# %%
current_date_time.year
# Out:
# 2025

# %% [markdown]
# # Framework -Package /Lib-Module-Functions

# %% [markdown]
# ### Python Module

# %% [markdown]
# - Modules refer to a file containing Python statements and definitions.
# - A file containing Python code, for example: new.py, is called a module, and its module name would be new.
# - We use modules to break down large programs into small manageable and organized files. Furthermore, modules provide reusability of code.
# - We can define our most used functions in a module and import it, instead of copying their definitions into different programs.

# %% [markdown]
# data_collection.py
#
# pre_processing.py
#
# EDA.py
#
# datebase.py
#
# modeling.py

# %% [raw]
# Module:A module is a single file that contains Python code. This code can include functions, classes, variables, and runnable code.
#
# Packages:A package is a collection of modules organized in directories. It allows you to group related modules together.
#
# Library:: Python comes with a "standard library" that includes a wide range of modules and packages for common tasks, such as file I/O, system calls, and data manipulation.

# %%
pip freeze
# Out:
# absl-py==2.0.0
# aiobotocore @ file:///C:/b/abs_74o47svlua/croot/aiobotocore_1680004300264/work
# aiofiles @ file:///C:/b/abs_9ex6mi6b56/croot/aiofiles_1683773603390/work
# aiohttp @ file:///C:/ci_311/aiohttp_1676432932774/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# aiosqlite @ file:///C:/b/abs_9djc_0pyi3/croot/aiosqlite_1683773915844/work
# alabaster @ file:///home/ktietz/src/ci/alabaster_1611921544520/work
# anaconda-catalogs @ file:///C:/b/abs_8btyy0o8s8/croot/anaconda-catalogs_1685727315626/work
# anaconda-client==1.11.3
# anaconda-navigator==2.4.2
# anaconda-project @ file:///C:/ci_311/anaconda-project_1676458365912/work
# annotated-types==0.6.0
# anyascii==0.3.2
# anyio @ file:///C:/ci_311/anyio_1676425491996/work/dist
# appdirs==1.4.4
# argon2-cffi @ file:///opt/conda/conda-bld/argon2-cffi_1645000214183/work
# ...

# %% [raw]
# The pip freeze command is used to output a list of installed Python packages in the current environment along with their versions.

# %% [markdown]
# https://docs.python.org/3/py-modindex.html

# %% [markdown]
# # How to import modules in Python?

# %% [markdown]
# We can import the definitions inside a module to another module or the interactive interpreter in Python.
#
# We use the import keyword to do this. To import our previously defined module example, we type the following in the Python prompt.

# %%
import math
#from math import sqrt
#from math import *

# %%
print(dir(math))
# Out:
# ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %%
math.sqrt(64)
# Out:
# 8.0

# %%
math.factorial(5)
# Out:
# 120

# %%
math.pi
# Out:
# 3.141592653589793

# %%
from math import sqrt,pi

# %%
sqrt(64)
# Out:
# 8.0

# %%
pi
# Out:
# 3.141592653589793

# %%
from math import*

# %%
pi
# Out:
# 3.141592653589793

# %%
print(pi)
# Out:
# 3.141592653589793

# %% [markdown]
# ### import all names

# %% [markdown]
# We can import all names(definitions) from a module using the following construct:

# %%
from math import *

# %%
from math import pow,exp

# %%
pow(4,2)
# Out:
# 16.0

# %%
exp(6)
# Out:
# 403.4287934927351

# %% [markdown]
# Importing everything with the asterisk (*) symbol is not a good programming practice. This can lead to duplicate definitions for an identifier. It also hampers the readability of our code.

# %% [markdown]
# ### datetime module

# %%
import datetime  #package
from datetime import datetime as dt
current_dat_time=dt.now()
current_dat_time
# Out:
# datetime.datetime(2025, 8, 14, 10, 31, 30, 913453)

# %%
current_dat_time.year
# Out:
# 2025

# %%
current_dat_time.day
# Out:
# 14

# %% [markdown]
# #### random module

# %%
import random

# %%
print(dir(random))
# Out:
# ['BPF', 'LOG4', 'NV_MAGICCONST', 'RECIP_BPF', 'Random', 'SG_MAGICCONST', 'SystemRandom', 'TWOPI', '_ONE', '_Sequence', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_accumulate', '_acos', '_bisect', '_ceil', '_cos', '_e', '_exp', '_fabs', '_floor', '_index', '_inst', '_isfinite', '_lgamma', '_log', '_log2', '_os', '_parse_args', '_pi', '_random', '_repeat', '_sha512', '_sin', '_sqrt', '_test', '_test_generator', '_urandom', 'betavariate', 'binomialvariate', 'choice', 'choices', 'expovariate', 'gammavariate', 'gauss', 'getrandbits', 'getstate', 'lognormvariate', 'main', 'normalvariate', 'paretovariate', 'randbytes', 'randint', 'random', 'randrange', 'sample', 'seed', 'setstate', 'shuffle', 'triangular', 'uniform', 'vonmisesvariate', 'weibullvariate']

# %%
random.randint(6,7)
# Out:
# 7

# %%
random.randint(1,10)
# Out:
# 9

# %%
random.random()
# Out:
# 0.31118568286235937

# %%
import pandas as pd

# %%
print(dir(pd))
# Out:
# ['ArrowDtype', 'BooleanDtype', 'Categorical', 'CategoricalDtype', 'CategoricalIndex', 'DataFrame', 'DateOffset', 'DatetimeIndex', 'DatetimeTZDtype', 'ExcelFile', 'ExcelWriter', 'Flags', 'Float32Dtype', 'Float64Dtype', 'Grouper', 'HDFStore', 'Index', 'IndexSlice', 'Int16Dtype', 'Int32Dtype', 'Int64Dtype', 'Int8Dtype', 'Interval', 'IntervalDtype', 'IntervalIndex', 'MultiIndex', 'NA', 'NaT', 'NamedAgg', 'Period', 'PeriodDtype', 'PeriodIndex', 'RangeIndex', 'Series', 'SparseDtype', 'StringDtype', 'Timedelta', 'TimedeltaIndex', 'Timestamp', 'UInt16Dtype', 'UInt32Dtype', 'UInt64Dtype', 'UInt8Dtype', '__all__', '__builtins__', '__cached__', '__doc__', '__docformat__', '__file__', '__git_version__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', '_built_with_meson', '_config', '_is_numpy_dev', '_libs', '_pandas_datetime_CAPI', '_pandas_parser_CAPI', '_testing', '_typing', '_version_meson', 'annotations', 'api', 'array', 'arrays', 'bdate_range', 'compat', 'con
# ...

# %%
l=[1,2,4,5,7,8]
data=pd.DataFrame(l,columns=["numbers"])
data
# Out:
#    numbers
# 0        1
# 1        2
# 2        4
# 3        5
# 4        7
# 5        8

# %%
data.mean()
# Out:
# numbers    4.5
# dtype: float64

# %%
import statistics

# %%
print(dir(statistics))
# Out:
# ['Counter', 'Decimal', 'Fraction', 'LinearRegression', 'NormalDist', 'StatisticsError', '_SQRT2', '__all__', '__annotations__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_coerce', '_convert', '_decimal_sqrt_of_frac', '_exact_ratio', '_fail_neg', '_float_sqrt_of_frac', '_integer_sqrt_of_frac_rto', '_isfinite', '_mean_stdev', '_normal_dist_inv_cdf', '_sqrt_bit_width', '_ss', '_sum', 'bisect_left', 'bisect_right', 'correlation', 'covariance', 'defaultdict', 'erf', 'exp', 'fabs', 'fmean', 'fsum', 'geometric_mean', 'groupby', 'harmonic_mean', 'hypot', 'linear_regression', 'log', 'math', 'mean', 'median', 'median_grouped', 'median_high', 'median_low', 'mode', 'mul', 'multimode', 'namedtuple', 'numbers', 'pstdev', 'pvariance', 'quantiles', 'random', 'reduce', 'repeat', 'sqrt', 'stdev', 'sys', 'tau', 'variance']

# %%
statistics.mean(l)
# Out:
# 4.5
