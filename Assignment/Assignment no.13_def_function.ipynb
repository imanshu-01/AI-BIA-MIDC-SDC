# %% [markdown]
# # Assignment no.13_def_function By H
# ...........

# %% [markdown]
# ### 1. Write a function that calculates the area and perimeter of a rectangle given its length and width as parameters.

# %%
def rectangle(length, width):
    area = length * width
    perimeter = 2 * (length + width)
    return area, perimeter

print(rectangle(4, 3))
# Out:
# (12, 14)

# %% [markdown]
# ### 2. Create a function that takes an integer as input and returns "Even" if it's even and "Odd" if it's odd.

# %%
def even_odd(num):
    if num % 2 == 0:
        return "Even"
    else:
        return "Odd"

print(even_odd(7))
# Out:
# Odd

# %% [markdown]
# ### 3. Define a function that takes a string as input and returns the reverse of that string.

# %%
def reverse_string(text):
    return text[::-1]

print(reverse_string("Himanshu"))
# Out:
# uhsnamiH

# %% [markdown]
# ### 4. Write a function that takes three numbers as input and returns the maximum of the three.

# %%
def max_of_three(a, b, c):
    return max(a, b, c)

print(max_of_three(10, 25, 15))
# Out:
# 25

# %% [markdown]
# ### 5. Create a function that calculates the factorial of a given positive integer.

# %%
def factorial(n):
    result = 1
    for i in range(1, n+1):
        result *= i
    return result

print(factorial(5))
# Out:
# 120

# %% [markdown]
# ### 6. Define a function that checks whether a given string is a palindrome (reads the same backward as forward).

# %%
def is_palindrome(word):
    return word == word[::-1]

print(is_palindrome("madam"))
# Out:
# True

# %% [markdown]
# ### 7. Write a function that counts the number of vowels in a given string.

# %%
def count_vowels(text):
    vowels = "aeiouAEIOU"
    count = 0
    for ch in text:
        if ch in vowels:
            count += 1
    return count

print(count_vowels("Education"))
# Out:
# 5

# %% [markdown]
# ### 8. Create a function that takes two numbers as input, a base and an exponent, and returns the result of the base raised to the exponent.

# %%
def power(base, exp):
    return base ** exp

print(power(2, 3))
# Out:
# 8

# %% [markdown]
# ### 9. Define a function that takes a list of numbers as input and returns the sum of all the numbers in the list.

# %%
def list_sum(numbers):
    return sum(numbers)

print(list_sum([1, 2, 3, 4]))
# Out:
# 10

# %% [markdown]
# ### 10. Write a function to generate the Fibonacci series up to a given number of terms.

# %%
def fibonacci(n):
    a, b = 0, 1
    series = []
    for i in range(n):
        series.append(a)
        a, b = b, a + b
    return series

print(fibonacci(5))
# Out:
# [0, 1, 1, 2, 3]

# %% [markdown]
# ### 11. Create a function that checks if a given number is prime.

# %%
def Ahm_prime(num):
    if num <= 1:
        return False
    for i in range(2, num):
        if num % i == 0:
            return False
    return True

print(Ahm_prime(10))
# Out:
# False

# %% [markdown]
# ### 12. Define a function that calculates the square root of a positive number using the Newton-Raphson method.

# %%
def square_root(num):
    guess = num / 2
    for i in range(10):
        guess = (guess + num / guess) / 2
    return guess

print(square_root(16))
# Out:
# 4.0

# %% [markdown]
# ## 13. Write a function that takes a string as input and returns the same string with all its letters capitalized.

# %%
def capitalize_text(text):
    return text.upper()

print(capitalize_text("python"))
# Out:
# PYTHON

# %% [markdown]
# ### 14. Create a function that calculates the average of a list of numbers.

# %%
def average(numbers):
    return sum(numbers) / len(numbers)

print(average([10, 20, 30]))
# Out:
# 20.0

# %% [markdown]
# ### 15. Define a function that checks if a given year is a leap year.

# %%
def leap_year(year):
    return (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0)

print(leap_year(2024))
# Out:
# True

# %% [markdown]
# ### 16. Write a function that takes a list as input and returns a new list containing only the unique elements.

# %%
def unique_list(lst):
    return list(set(lst))

print(unique_list([1, 2, 2, 3, 4, 4]))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### 17. Create a function that takes a positive integer as input and returns a list of its factors.

# %%
def factors(num):
    result = []
    for i in range(1, num+1):
        if num % i == 0:
            result.append(i)
    return result

print(factors(12))
# Out:
# [1, 2, 3, 4, 6, 12]

# %% [markdown]
# ### 18. Define a function that counts the number of words in a given sentence.

# %%
def word_count(sentence):
    return len(sentence.split())

print(word_count("Python is very easy"))
# Out:
# 4

# %% [markdown]
# ### 19. Write a function that finds the longest word in a given sentence.

# %%
def longest_word(sentence):
    words = sentence.split()
    return max(words, key=len)

print(longest_word("Python programming is interesting"))
# Out:
# programming

# %% [markdown]
# ### 20. Create a function that calculates the greatest common divisor (GCD) and least common multiple (LCM) of two numbers.

# %%
def gcd_lcm(a, b):
    import math
    gcd = math.gcd(a, b)
    lcm = (a * b) // gcd
    return gcd, lcm

print(gcd_lcm(12, 18))
# Out:
# (6, 36)

# %% [markdown]
# ### 21. What is the purpose of using functions in a program?

# %% [markdown]
# Functions help to reuse code, reduce repetition, and make programs easy to understand.

# %% [markdown]
# ### 22. What is the return statement used for in a function?

# %% [markdown]
# The return statement sends a value back from a function.

# %% [markdown]
# ### 23. Can a function have multiple return statements?

# %% [markdown]
# Yes, a function can have more than one return statement.

# %% [markdown]
# ### 24. What is the difference between a built-in function and a user-defined function?

# %% [markdown]
# Built-in functions are already provided by Python. User-defined functions are created by programmers.

# %% [markdown]
# ### 25. what is the difference between local variable and global variable?

# %% [markdown]
# Local variables work inside a function. Global variables work everywhere in the program.

# %% [markdown]
# ### 26. What happens if a return statement is missing in a function?

# %% [markdown]
# If return is missing, the function returns None.

# %% [markdown]
# ### 27. How can you import and use functions from another Python file

# %% [markdown]
# Use `import filename` or `from filename import function_name`.
